# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0

def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# idea by https://github.com/rndbrtrnd/udacity-deep-learning/blob/master/6_lstm.ipynb

# %%
num_nodes = 64
embedding_size = 128
graph = tf.Graph()

with graph.as_default():
  
  # Parameters:
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  #think a lot of time then glance at https://github.com/magicly/udacity-ud730/blob/master/6_lstm.ipynb thanks
  ifcox = tf.concat([ix,fx,cx,ox],1)
  ifcom = tf.concat([im,fm,cm,om],1)
  ifcob = tf.concat([ib,fb,cb,ob],1)
 # print(ifcox.shape)
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
   # print(i.shape)
    #embed = tf.nn.embedding_lookup(embeddings, i)  no need here
    #print(embed.shape)
    ifco_input = tf.matmul(i,ifcox) + tf.matmul(o,ifcom) +ifcob
    input_ifco,forget_ifco,update_ifco,output_ifco = tf.split(ifco_input,4,1)
    #print(input_ifco.shape)
    input_gate = tf.sigmoid(input_ifco)
    
    forget_gate = tf.sigmoid(forget_ifco)
    update = update_ifco
    output_gate = tf.sigmoid(output_ifco)
    state = forget_gate * state + input_gate * tf.tanh(update)
    #print((output_gate * tf.tanh(state)).shape)
    return output_gate * tf.tanh(state), state
    
    
  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.int32, shape=[batch_size,vocabulary_size]))# shape no change ,i spend a lot of time to think in here an there!
  
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.
  
  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(embeddings,tf.argmax(i, axis=1))#  choose the index of the max value in every row
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)
  #  print(output.shape)
  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs,0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits)) #no change !!

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)
  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
   # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(embeddings,tf.argmax(sample_input, axis=1))
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100
from time import time
start = time()
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
      end = time()
      total = end -start
      print(total)
# Out:
# Initialized
# Average loss at step 0: 3.294559 learning rate: 10.000000
# Minibatch perplexity: 26.97
# ================================================================================
# qlxmy  qfurv h xlipy ionmmme wt pz vs  o o zsqf vevt ckn dnebhqyqpuyziripastb os
# xdairwejcmyfoqvt  nazwoerybpfbrp a g wi nh kviifjoavrvl sgokerlsofoedvbds frw ic
# ybxtlr u olgis ciodjcen w o ggwee h tjtne ph jntd te nm mco vruba mrcibwdrfg aso
# pramfdts t y secfefwd a o q wimfflvsjgybh v js ehrw nsq y bcsdent emit zsdpss ha
# dis zg  u hoxnrvgaua e npiv ay dga rlrbrupyio  h zioc z c gel n itesg ghecxopy
# ================================================================================
# Validation set perplexity: 19.00
# 2.560401439666748
# Average loss at step 100: 2.296870 learning rate: 10.000000
# Minibatch perplexity: 8.32
# Validation set perplexity: 8.86
# 4.205906867980957
# Average loss at step 200: 2.007827 learning rate: 10.000000
# Minibatch perplexity: 6.97
# Validation set perplexity: 7.08
# 5.884900093078613
# Average loss at step 300: 1.923574 learning rate: 10.000000
# Minibatch perplexity: 6.75
# Validation set perplexity: 6.76
# 7.544907331466675
# Average loss at step 400: 1.863597 learning rate: 10.000000
# Minibatch perplexity: 7.18
# Validation set perplexity: 6.58
# 9.264402389526367
# Average loss at step 500: 1.827592 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 6.30
# 10.938414812088013
# Average loss at step 600: 1.813047 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 6.01
# 12.630402565002441
# Average loss at step 700: 1.772435 learning rate: 10.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 5.73
# 14.33390212059021
# Average loss at step 800: 1.735157 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.62
# 16.00191569328308
# Average loss at step 900: 1.755207 learning rate: 10.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 5.52
# 17.689910888671875
# Average loss at step 1000: 1.759229 learning rate: 10.000000
# Minibatch perplexity: 5.55
# ================================================================================
# zed to the jame durie of cevily fure factral singdas in the southriso of eini su
# zedo north dity encerviation of repreetim succentary gree will extegral agent us
# x some four thu the and has the rebeime graguanats i of be with wifkenoyojes inf
# t didgethir have of of he bewhen compred the selfo heassuoppeer regisly be side
# jomin flere the frenched the remature if of nesphien didis to the pression dying
# ================================================================================
# Validation set perplexity: 5.45
# 19.589136123657227
# Average loss at step 1100: 1.721309 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.41
# 21.262207746505737
# Average loss at step 1200: 1.703914 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 5.07
# 22.9287052154541
# Average loss at step 1300: 1.683104 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.19
# 24.60170578956604
# Average loss at step 1400: 1.699769 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.08
# 26.287206172943115
# Average loss at step 1500: 1.688872 learning rate: 10.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 5.09
# 27.945706129074097
# Average loss at step 1600: 1.712872 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.29
# 29.55870795249939
# Average loss at step 1700: 1.675411 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 5.06
# 31.233206510543823
# Average loss at step 1800: 1.650368 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 5.04
# 32.907206296920776
# Average loss at step 1900: 1.620481 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 5.00
# 34.516207218170166
# Average loss at step 2000: 1.670971 learning rate: 10.000000
# Minibatch perplexity: 5.46
# ================================================================================
# s created winduakli cinet on a lather yames hy  the amonnesding lits currates as
# ing in the ages id modo lim four dia zero for american lating allywo diciam yeal
# da succh vark geouthn diving worse libenity deperminationals s less dualing in h
# dificiann and mirdrad not state negiont to unage at giving is this stends than o
# butala sai dirconcis and can g endis de sparaded to is simp to solity andrating
# ================================================================================
# Validation set perplexity: 4.97
# 36.422094106674194
# Average loss at step 2100: 1.661514 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.83
# 38.08409237861633
# Average loss at step 2200: 1.656833 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 4.93
# 39.76809215545654
# Average loss at step 2300: 1.615588 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.75
# 41.60209250450134
# Average loss at step 2400: 1.639384 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.68
# 43.28009247779846
# Average loss at step 2500: 1.669199 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.71
# 45.036102056503296
# Average loss at step 2600: 1.644906 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 4.66
# 46.682594537734985
# Average loss at step 2700: 1.647269 learning rate: 10.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.74
# 48.584593772888184
# Average loss at step 2800: 1.639467 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 4.46
# 50.327595710754395
# Average loss at step 2900: 1.638737 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.68
# 52.038230419158936
# Average loss at step 3000: 1.641302 learning rate: 10.000000
# Minibatch perplexity: 4.89
# ================================================================================
# n n and wereth in aramay sadica seven thus one was metnafts former ray campished
# has lirmo cristian with fism to becaused as count t diffurdeme seven three the t
# can site the completers by vasely reathed by socany and amerir in varity the peo
# smpequing coodstiins of it deccaction fould age was and agriston salatic of stri
# jom ree dead pnelless one inscaclarin chann and sell paarth are of formationy ha
# ================================================================================
# Validation set perplexity: 4.75
# 54.03478646278381
# Average loss at step 3100: 1.630018 learning rate: 10.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 4.54
# 55.716286420822144
# Average loss at step 3200: 1.643208 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.61
# 57.37729597091675
# Average loss at step 3300: 1.634259 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.66
# 59.09628701210022
# Average loss at step 3400: 1.665306 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.61
# 60.79079294204712
# Average loss at step 3500: 1.659003 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.67
# 62.464786529541016
# Average loss at step 3600: 1.666286 learning rate: 10.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 4.62
# 64.10030031204224
# Average loss at step 3700: 1.645699 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.58
# 65.7813446521759
# Average loss at step 3800: 1.650116 learning rate: 10.000000
# Minibatch perplexity: 5.65
# Validation set perplexity: 4.67
# 67.51610827445984
# Average loss at step 3900: 1.641756 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.62
# 69.23256587982178
# Average loss at step 4000: 1.655935 learning rate: 10.000000
# Minibatch perplexity: 4.70
# ================================================================================
# mater b only incoloments mossion lay to unizences for astorca early beer the pow
# za the bove of he the second choy eats inclusty a directed tor the jeried of to
# mastins n reght bulsl for kerempine one stele to his most play loesponding its a
# y the b terple the forms meterpreces when mijy the norcmas yemallane the cathemi
#  doup praman by debalaftication zefod wictespode appear the gols infineturial so
# ================================================================================
# Validation set perplexity: 4.55
# 71.10156726837158
# Average loss at step 4100: 1.638147 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.65
# 72.78509163856506
# Average loss at step 4200: 1.644380 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.54
# 74.4683141708374
# Average loss at step 4300: 1.621829 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.61
# 76.15731525421143
# Average loss at step 4400: 1.618098 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.43
# 77.83888387680054
# Average loss at step 4500: 1.621232 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 4.59
# 79.51044344902039
# Average loss at step 4600: 1.621922 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.67
# 81.20744276046753
# Average loss at step 4700: 1.632072 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.44
# 82.86003875732422
# Average loss at step 4800: 1.643617 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.47
# 84.63903856277466
# Average loss at step 4900: 1.643802 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.62
# 86.36953902244568
# Average loss at step 5000: 1.617906 learning rate: 1.000000
# Minibatch perplexity: 4.41
# ================================================================================
# trations of the being himmes whightered red on eight niblese overl is fols biori
# ble uning this can pagre often and polay calulty as devered with lake over emmen
# national eight juch of but of force gowiness vece when or s six four four and f
# hot a preess in the penaltion of that almostic la less who of contulism born you
# jusicnien sovenentasl been commonth many that to a nevire by mecheas rangends ma
# ================================================================================
# Validation set perplexity: 4.54
# 88.34605526924133
# Average loss at step 5100: 1.596165 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.28
# 90.05005407333374
# Average loss at step 5200: 1.569470 learning rate: 1.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 4.21
# 91.807053565979
# Average loss at step 5300: 1.557808 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.24
# 93.52461791038513
# Average loss at step 5400: 1.554058 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.21
# 95.26283764839172
# Average loss at step 5500: 1.546681 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.20
# 96.92533779144287
# Average loss at step 5600: 1.557472 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.18
# 98.61621832847595
# Average loss at step 5700: 1.545672 learning rate: 1.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.15
# 100.25072836875916
# Average loss at step 5800: 1.555663 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.17
# 101.99086713790894
# Average loss at step 5900: 1.552699 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.17
# 103.67637538909912
# Average loss at step 6000: 1.526793 learning rate: 1.000000
# Minibatch perplexity: 4.98
# ================================================================================
# onsical of a many bathan ration as assocheding heysten a ausonic the hudes posti
# ret excepdent ispeay to a power one three four riginstiviting mgans discuph the
# on been also faple a doc the aurage this that the gatled poart as be make as bir
# umed as centrinal prex are compleft into that well reclaugion the most edite bal
# quest with dil s hap this use with develt be a game than the david of the but te
# ================================================================================
# Validation set perplexity: 4.16
# 105.67687511444092
# Average loss at step 6100: 1.540660 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.17
# 107.44112300872803
# Average loss at step 6200: 1.515091 learning rate: 1.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.17
# 109.0766351222992
# Average loss at step 6300: 1.521740 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.14
# 110.69151902198792
# Average loss at step 6400: 1.517521 learning rate: 1.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 4.14
# 112.46601796150208
# Average loss at step 6500: 1.534677 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.15
# 114.16902136802673
# Average loss at step 6600: 1.574380 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.14
# 115.84374260902405
# Average loss at step 6700: 1.553814 learning rate: 1.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.16
# 117.54827284812927
# Average loss at step 6800: 1.578740 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.14
# 119.27727627754211
# Average loss at step 6900: 1.558157 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.16
# 120.98745465278625
# Average loss at step 7000: 1.547558 learning rate: 1.000000
# Minibatch perplexity: 4.77
# ================================================================================
# ney hight its in one niera lower disting known which lithalty exected nine seven
# k and diskitic of skis pocubulation the ansell known play s herther not vara has
# s one nine eight zero seven zero six uncontiley that i m wairvating the aral gia
# quisksh and these g of a landbections that wester countenets jearaf age worlver
# anes by the fultion a unfailangismas policy z sometiment reavlesh abitee is this
# ================================================================================
# Validation set perplexity: 4.15
# 122.93544340133667

# %% [markdown]
# we can see the loss is lower than the simple model but spend much more time.
